# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random as rnd
fuel = pd.read_csv(r'E:\PythonAnacondaScripts\course-files\fuel.csv', usecols = ['Vehicle ID','Year','Make','Model',
                'Class','Fuel Type','Combined MPG (FT1)','Start Stop Technology'], low_memory=False, index_col = 'Vehicle ID')
fuel
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# ...          ...         ...                 ...                          ...
# 32060       2012  Mitsubishi              Lancer                 Compact Cars
# 32063       2012  Mitsubishi          Lancer AWD                 Compact Cars
# 32065       2012  Mitsubishi    Lancer Evolution                 Compact Cars
# 32064       2012  Mitsubishi    Lancer Evolution                 Compact Cars
# 32106       2012   Mitsubish                 NaN                          NaN
#
# ...

# %%
listOfCars = [ 'Renault', 'Toyota','Ford']
isInList = fuel['Model'].isin(listOfCars)
isInList
# Out:
# Vehicle ID
# 26587    False
# 27705    False
# 26561    False
# 27681    False
# 27550    False
#          ...
# 32060    False
# 32063    False
# 32065    False
# 32064    False
# 32106    False
# Name: Model, Length: 31684, dtype: bool

# %%
fuel[isInList]
# Out:
# Empty DataFrame
# Columns: [Year, Make, Model, Class, Fuel Type, Combined MPG (FT1), Start Stop Technology]
# Index: []

# %%
isNoStartStopDefined = fuel['Start Stop Technology'].isnull()

# %%
isNoStartStopDefined
# Out:
# Vehicle ID
# 26587    True
# 27705    True
# 26561    True
# 27681    True
# 27550    True
#          ...
# 32060    True
# 32063    True
# 32065    True
# 32064    True
# 32106    True
# Name: Start Stop Technology, Length: 31684, dtype: bool

# %%
fuel[isNoStartStopDefined]
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# ...          ...         ...                 ...                          ...
# 32060       2012  Mitsubishi              Lancer                 Compact Cars
# 32063       2012  Mitsubishi          Lancer AWD                 Compact Cars
# 32065       2012  Mitsubishi    Lancer Evolution                 Compact Cars
# 32064       2012  Mitsubishi    Lancer Evolution                 Compact Cars
# 32106       2012   Mitsubish                 NaN                          NaN
#
# ...

# %%
isStartStopDefined = fuel['Start Stop Technology'].notnull()

# %%
isStartStopDefined
# Out:
# Vehicle ID
# 26587    False
# 27705    False
# 26561    False
# 27681    False
# 27550    False
#          ...
# 32060    False
# 32063    False
# 32065    False
# 32064    False
# 32106    False
# Name: Start Stop Technology, Length: 31684, dtype: bool

# %%
fuel[isStartStopDefined]
# Out:
#             Year           Make                      Model  \
# Vehicle ID
# 30976       1998      Chevrolet               S10 Electric
# 30977       1998      Chevrolet               S10 Electric
# 30975       1998          Honda                    EV Plus
# 30973       1999          Dodge  Caravan/Grand Caravan 2WD
# 30971       1999           Ford          Ranger Pickup 2WD
# ...          ...            ...                        ...
# 31926       2012          Lexus                    RX 450h
# 31971       2012          Lexus                RX 450h AWD
# 31395       2012        Lincoln             MKZ Hybrid FWD
# 31799       2012  Mercedes-Benz                S400 Hybrid
# 31673       2012     Mitsubishi                     i-MiEV
#
#                                   Class    Fuel Type  Combined MPG (FT1)  \
# Vehicle ID
# 30976           Small Pickup Trucks 2WD  Electricity                55.0
# 30977           Small Pickup Trucks 2WD  Electricity                28.0
# ...

# %%
mpg50_60 = fuel['Combined MPG (FT1)'].between(50,60)

# %%
mpg50_60
# Out:
# Vehicle ID
# 26587    False
# 27705    False
# 26561    False
# 27681    False
# 27550    False
#          ...
# 32060    False
# 32063    False
# 32065    False
# 32064    False
# 32106    False
# Name: Combined MPG (FT1), Length: 31684, dtype: bool

# %%
fuel[mpg50_60]
# Out:
#             Year       Make              Model                       Class  \
# Vehicle ID
# 30976       1998  Chevrolet       S10 Electric     Small Pickup Trucks 2WD
# 30971       1999       Ford  Ranger Pickup 2WD  Standard Pickup Trucks 2WD
# 30966       2000       Ford  Ranger Pickup 2WD  Standard Pickup Trucks 2WD
# 30967       2000       Ford  Ranger Pickup 2WD  Standard Pickup Trucks 2WD
# 15606       2000      Honda            Insight                 Two Seaters
# 30965       2001       Ford  Ranger Pickup 2WD  Standard Pickup Trucks 2WD
# 16447       2001      Honda            Insight                 Two Seaters
# 17355       2002      Honda            Insight                 Two Seaters
# 18313       2003      Honda            Insight                 Two Seaters
# 19357       2004      Honda            Insight                 Two Seaters
# 20479       2005      Honda            Insight                 Two Seaters
# ...
