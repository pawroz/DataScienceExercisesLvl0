# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random as rd
fuel = pd.read_csv('course-files/fuel.csv', low_memory=False, 
                   index_col = 'Vehicle ID',
                   usecols = ['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3816310f0b16> in <module>
#       6 fuel = pd.read_csv('course-files/fuel.csv', low_memory=False,
#       7                    index_col = 'Vehicle ID',
# ----> 8                    usecols = ['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'])
#
# ...

# %%
fuel["Make"].value_counts()
# Out:
# Vehicle ID
# 26587    Alfa Romeo
# 27705    Alfa Romeo
# 26561    Alfa Romeo
# 27681    Alfa Romeo
# 27550    AM General
#             ...
# 32060    Mitsubishi
# 32063    Mitsubishi
# 32065    Mitsubishi
# 32064    Mitsubishi
# 32106     Mitsubish
# Name: Make, Length: 31684, dtype: object

# %%
fuel.sample(frac=1)
# Out:
#             Year      Make                Model                        Class  \
# Vehicle ID
# 22265       2006      Ford    Ranger Pickup 4WD   Standard Pickup Trucks 4WD
# 11460       1994   Mercury   Villager FWD Wagon     Special Purpose Vehicles
# 5686        1989  Chrysler          LeBaron GTS                 Midsize Cars
# 29442       2010      Ford    Escape Hybrid FWD  Sport Utility Vehicle - 2WD
# 6123        1989       GMC      Sierra 1500 4WD       Standard Pickup Trucks
# ...          ...       ...                  ...                          ...
# 1820        1986      Ford              Mustang              Subcompact Cars
# 2633        1986     Dodge    B150/B250 Van 2WD                         Vans
# 4314        1988   Pontiac  Sunbird Convertible              Subcompact Cars
# 18668       2003    Jaguar             S-Type R                 Midsize Cars
# 12580       1996     Dodge              Stealth              Subcompact Cars
#
# ...

# %%
len(fuel)
# Out:
# 31684

# %%
fuel['Combined KPL'] = fuel['Combined MPG (FT1)']  * 1.609 / 3.78

# %%
fuel.insert(loc = 4, labels='liters per km', value = (100 / fuel["Combined KPL"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-192e16b0692b> in <module>
# ----> 1 fuel.insert(loc = 4, labels=26587, value = (100 / fuel["Combined KPL"]))
#
# TypeError: insert() got an unexpected keyword argument 'labels'

# %%
fuel.drop(labels=27705, inplace=True)

# %%
fuel
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# 28426       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
# 27549       1984  AM General    FJ8c Post Office  Special Purpose Vehicle 2WD
# ...          ...         ...                 ...                          ...
# 32060       2012  Mitsubishi              Lancer                 Compact Cars
# 32063       2012  Mitsubishi          Lancer AWD                 Compact Cars
# 32065       2012  Mitsubishi    Lancer Evolution                 Compact Cars
# 32064       2012  Mitsubishi    Lancer Evolution                 Compact Cars
# 32106       2012   Mitsubish                 NaN                          NaN
#
# ...
