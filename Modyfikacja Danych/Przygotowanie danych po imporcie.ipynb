# %%
import pandas as pd
import numpy as np
fb = pd.read_csv(r'E:\PythonAnacondaScripts\course-files\mrbean_facebook_statuses_with_nulls.csv', usecols = [ "status_message", "status_type", "link_name", "num_reactions", "num_shares", "num_likes"])
fb.head()
# Out:
#                                       status_message  \
# 0  It's time for Mr Bean and Teddy to get ready f...
# 1                                                NaN
# 2                                                NaN
# 3  Mr Bean is ready to do some shopping but bewar...
# 4                                                NaN
#
#                            link_name status_type  num_reactions  num_shares  \
# 0  Mr Bean - Preparing To Go Camping       video        16570.0       338.0
# 1                    Timeline Photos       photo       119886.0      1657.0
# 2                    Timeline Photos       photo            NaN     10050.0
# 3                    www.youtube.com       video        20913.0       257.0
# 4                    Timeline Photos       photo       223602.0      2228.0
#
#    num_likes
# 0      16079
# 1     114008
# 2     218579
# 3      20338
# 4     215591

# %%
fb.info(memory_usage= 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   status_message  40 non-null     object
#  1   link_name       56 non-null     category
#  2   status_type     56 non-null     category
#  3   num_reactions   56 non-null     int32
#  4   num_shares      56 non-null     int32
#  5   num_likes       56 non-null     int64
# dtypes: category(2), int32(2), int64(1), object(1)
# memory usage: 12.2 KB

# %%
fb['status_message'].nunique()
fb['status_message'].unique()
# Out:
# array(["It's time for Mr Bean and Teddy to get ready for their camping trip!",
#        nan,
#        'Mr Bean is ready to do some shopping but beware - Teddy Thieves are on the loose!',
#        "Mr. Bean's sweet treat causes him pain!",
#        "Mr Bean's chasing a ray of sunshine!\r\nhttps://www.youtube.com/watch?v=c-AhlualVO0",
#        'Mr Bean is enjoying the sunshine....that is until someone gets in the way!\r\nhttps://youtu.be/EB_HBrKEgzM',
#        'Mr Bean competes with a Royal Guard.  Can he break his focus? https://www.youtube.com/watch?v=hcSP39U4EgU',
#        "HAPPY GEEK PRIDE DAY! Watch Mr Bean's geeky moments.\r\nhttps://youtu.be/6aK2CKrdjbE",
#        "Cooking Sunday lunch? Here's how not to do it! \r\nhttps://www.youtube.com/watch?v=2545atoypgs",
#        'Mr Bean shows you how to get that all important parking spot! \r\nhttps://www.youtube.com/watch?v=LtQyyzpzvV0',
# ...

# %%
fb['status_type'] = fb['status_type'].astype('category')

# %%
fb['link_name'] = fb['link_name'].astype('category')

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   status_message  40 non-null     object
#  1   link_name       56 non-null     category
#  2   status_type     56 non-null     category
#  3   num_reactions   54 non-null     float64
#  4   num_shares      56 non-null     float64
#  5   num_likes       56 non-null     int64
# dtypes: category(2), float64(2), int64(1), object(1)
# memory usage: 3.6+ KB

# %%
fb['num_reactions'] = fb['num_reactions'].fillna(value= 0)
fb['num_shares'] = fb['num_shares'].fillna(value= 0)
fb['num_reactions'] = fb['num_reactions'].astype('int')
fb['num_shares'] = fb['num_shares'].astype('int')

# %%
fb.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   status_message  40 non-null     object
#  1   link_name       56 non-null     category
#  2   status_type     56 non-null     category
#  3   num_reactions   56 non-null     int32
#  4   num_shares      56 non-null     int32
#  5   num_likes       56 non-null     int64
# dtypes: category(2), int32(2), int64(1), object(1)
# memory usage: 12.2 KB
